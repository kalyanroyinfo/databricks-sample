# %%
customers_df=spark.sql("SELECT * from json.`/Volumes/gizmobox/landing/operational_data/customers/`")
display(customers_df)

# %%
customers_df.display()

# %%
customers_df = spark.sql("""
CREATE OR REPLACE TEMP VIEW tv_customers AS 
SELECT * FROM json.`/Volumes/gizmobox/landing/operational_data/customers/`
""")

# %%
# %sql
SELECT * FROM tv_customers;

# %%
spark.read.format('json').load("/Volumes/gizmobox/landing/operational_data/customers/")

# %%
spark.table('gizmobox.bronze.addresses')
