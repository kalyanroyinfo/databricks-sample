# %%
# %sql
SELECT * FROM gizmobox.bronze.memberships;

# %%
# %sql
SELECT
  regexp_extract(path,'.*/([0-9]+)\\.png$') AS customer_id,
  content AS membership_card
FROM
  gizmobox.bronze.memberships;

# %%
# %sql
CREATE TABLE gizmobox.silver.memberships
AS
SELECT
  regexp_extract(path,'.*/([0-9]+)\\.png$') AS customer_id,
  content AS membership_card
FROM
  gizmobox.bronze.memberships;

# %%
# %sql
SELECT * FROM gizmobox.silver.memberships;
