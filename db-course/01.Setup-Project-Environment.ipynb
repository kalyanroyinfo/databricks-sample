# %%
# %fs ls 'abfss://gizmobox@ukwestadls.dfs.core.windows.net/landing/external_data/'

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS dea_course_ext_dl_gizmobox
    URL 'abfss://gizmobox@ukwestadls.dfs.core.windows.net'
    WITH (STORAGE CREDENTIAL `dea-course-ext-sc`)
    COMMENT 'External Location'

# %%
# %sql
SHOW CATALOGS;

# %%
# %sql
CREATE CATALOG  IF NOT EXISTS  gizmobox
      MANAGED LOCATION 'abfss://gizmobox@ukwestadls.dfs.core.windows.net'
      COMMENT 'This is Catalog for gizmobox Data Lakehouse';

# %%
# %sql
select current_catalog();

# %%
# %sql
USE CATALOG gizmobox;

# %%
# %sql
select current_catalog();

# %%
# %sql

USE CATALOG gizmobox;

CREATE SCHEMA  IF NOT EXISTS  landing
      MANAGED LOCATION 'abfss://gizmobox@ukwestadls.dfs.core.windows.net/landing'
      COMMENT 'This is landing schema for gizmobox';

CREATE SCHEMA  IF NOT EXISTS  bronze
      MANAGED LOCATION 'abfss://gizmobox@ukwestadls.dfs.core.windows.net/bronze'
      COMMENT 'This is landing schema for gizmobox';

CREATE SCHEMA  IF NOT EXISTS  silver
      MANAGED LOCATION 'abfss://gizmobox@ukwestadls.dfs.core.windows.net/silver'
      COMMENT 'This is landing schema for gizmobox';

CREATE SCHEMA  IF NOT EXISTS  gold
      MANAGED LOCATION 'abfss://gizmobox@ukwestadls.dfs.core.windows.net/gold'
      COMMENT 'This is landing schema for gizmobox';

# %%
# %sql
SHOW SCHEMAS;

# %%
# %sql
USE CATALOG gizmobox;
USE SCHEMA landing;

CREATE EXTERNAL VOLUME IF NOT EXISTS  operational_data
     LOCATION 'abfss://gizmobox@ukwestadls.dfs.core.windows.net/landing/operational_data/';

CREATE EXTERNAL VOLUME IF NOT EXISTS  external_data
     LOCATION 'abfss://gizmobox@ukwestadls.dfs.core.windows.net/landing/external_data/';

# %%
# %fs ls /Volumes/gizmobox/landing/operational_data
