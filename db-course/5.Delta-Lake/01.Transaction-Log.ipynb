# %%
# %python
dbutils.widgets.text("container_name", "demo")
dbutils.widgets.text("storage_name", "deacoursestoragewestus2")

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS demo.delta_lake
  MANAGED LOCATION 'abfss://demo@oosstorage2.dfs.core.windows.net/delta_lake'

# %%
# %sql
CREATE TABLE IF NOT EXISTS demo.delta_lake.companies(
  company_name STRING,
  founded_date DATE,
  country STRING
);

# %%
# %sql
DESCRIBE EXTENDED demo.delta_lake.companies;

# %%
# %sql
INSERT into demo.delta_lake.companies VALUES ("test1","2024-11-11","abcd")

# %%
# %sql
SELECT * from demo.delta_lake.companies;

# %%
# %sql
INSERT into demo.delta_lake.companies VALUES 
("test2","1974-11-11","abcd1"),
("test3","1975-11-11","abcd2"),
("test4","1984-11-11","abcd3");

# %%
# %sql
INSERT into demo.delta_lake.companies VALUES 
("test5","1994-11-11","US"),
("test6","1995-11-11","India"),
("test7","20044-11-11","US");

# %%
# %sql
SELECT * from demo.delta_lake.companies;

# %%
# %sql
INSERT into demo.delta_lake.companies VALUES 
("test8","1995-11-11","US");

# %%
# %sql
INSERT into demo.delta_lake.companies VALUES 
("test9","1995-11-11","US");

# %%
# %sql
INSERT into demo.delta_lake.companies VALUES 
("test10","1995-11-11","US");

# %%
# %sql
INSERT into demo.delta_lake.companies VALUES 
("test11","1995-11-11","US");

# %%
# %sql
INSERT into demo.delta_lake.companies VALUES 
("test12","1995-11-11","US");

# %%
# %sql
INSERT into demo.delta_lake.companies VALUES 
("test13","1995-11-11","US");

# %%
# %sql
INSERT into demo.delta_lake.companies VALUES 
("test14","1995-11-11","US");

# %%
# %sql
INSERT into demo.delta_lake.companies VALUES 
("test15","1995-11-11","US");

# %%
# %sql
DROP TABLE demo.delta_lake.companies;

# %%
# %sql
SELECT * FROM demo.delta_lake.companies VERSION AS OF 2;

# %%
df = spark.read.format("delta").option("versionAsOf", 2).table("demo.delta_lake.companies")
display(df)
