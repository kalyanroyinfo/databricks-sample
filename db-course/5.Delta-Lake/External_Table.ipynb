# %%
# %sql
CREATE TABLE IF NOT EXISTS new_companies(
  company_name STRING,
  founded_date DATE,
  country STRING
)
LOCATION 'abfss://demo@oosstorage2.dfs.core.windows.net/delta_lake/new_companies';

# %%
# %sql
DESCRIBE EXTENDED new_companies;

# %%
# %sql
INSERT into new_companies VALUES 
("test13","1995-11-11","US");

# %%
# %sql
DROP TABLE new_companies;

# %%
# %sql
CREATE TABLE IF NOT EXISTS demo.delta_lake.csv_companies(
  company_name STRING,
  founded_date DATE,
  country STRING
) USING CSV
