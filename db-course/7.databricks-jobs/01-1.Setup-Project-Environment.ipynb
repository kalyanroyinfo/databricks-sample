-- %%
%sql
CREATE EXTERNAL LOCATION IF NOT EXISTS dea_course_ext_dl_demo
    URL 'abfss://demo@deacoursestoragewestus22.dfs.core.windows.net'
    WITH (STORAGE CREDENTIAL `dea_course_ext_sc`)
    COMMENT 'External Location for the demo storage account'

-- %%
CREATE CATALOG IF NOT EXISTS demo 
  MANAGED LOCATION 'abfss://demo@deacoursestoragewestus22.dfs.core.windows.net/'
