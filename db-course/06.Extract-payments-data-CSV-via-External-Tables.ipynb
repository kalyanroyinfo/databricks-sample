# %%
# %fs ls 'abfss://gizmobox@ukwestadls.dfs.core.windows.net/landing/external_data/payments'

# %%
# %sql
CREATE EXTERNAL LOCATION payments_loc
URL 'abfss://gizmobox@ukwestadls.dfs.core.windows.net/landing/external_data/payments'
WITH (STORAGE CREDENTIAL `dea-course-ext-sc`);

# %%
# %sql
CREATE EXTERNAL TABLE IF NOT EXISTS gizmobox.bronze.payments (
  payment_id INTEGER,
  order_id INTEGER,
  payment_timestamp TIMESTAMP,
  payment_status INTEGER,
  payment_method STRING
)
USING CSV
LOCATION '@dea_course_ext_dl_gizmobox/landing/external_data/payments';

# %%
# %sql
CREATE EXTERNAL TABLE IF NOT EXISTS gizmobox.bronze.payments (
  payment_id INTEGER,
  order_id INTEGER,
  payment_timestamp TIMESTAMP,
  payment_status INTEGER,
  payment_method STRING
)
USING CSV
LOCATION 'abfss://gizmobox@ukwestadls.dfs.core.windows.net/landing/external_data/payments';
