# %%
# The error is likely due to the use of backticks (`) around the path. 
# In Databricks magic commands, you should not use backticks. Use plain quotes or no quotes.

dbutils.fs.ls('/Volumes/gizmobox/landing/operational_data/memberships/')

# %%
# %fs ls /Volumes/gizmobox/landing/operational_data/memberships/

# %%
# %sql
select * from binaryFile.`/Volumes/gizmobox/landing/operational_data/memberships/*`

# %%
# %sql
CREATE or REPLACE VIEW gizmobox.bronze.memberships
AS
select * from binaryFile.`/Volumes/gizmobox/landing/operational_data/memberships/*`

# %%
# %sql
SELECT * FROM gizmobox.bronze.memberships;
