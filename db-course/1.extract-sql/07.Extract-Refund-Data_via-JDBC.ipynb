# %%
# %sql
CREATE SCHEMA IF NOT EXISTS hive_metastore.bronze;

# %%
# %sql
CREATE TABLE IF NOT EXISTS hive_metastore.bronze.refunds 
USING JDBC
OPTIONS(
  url "jdbc:sqlserver://kalyan-sql-server.database.windows.net:1433;database=gizmobox-db;encrypt=true;trustServerCertificate=false;loginTimeout=60;",
  driver "com.microsoft.sqlserver.jdbc.SQLServerDriver",
  dbtable "refunds",
  user "gizmoadmin",
  password "Himu@1512"
);

# %%
# %sql
DESC EXTENDED hive_metastore.bronze.refunds

# %%
# %sql
select * from hive_metastore.bronze.refunds
