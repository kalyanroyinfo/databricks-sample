# %%
# %python
dbutils.widgets.text("container_name", "gizmobox")
dbutils.widgets.text("storage_name", "deacoursestoragewestus2")

# %%
# %fs ls 'abfss://gizmobox@deacoursestoragewestus2.dfs.core.windows.net/landing/external_data/payments'

# %%
# %sql
CREATE EXTERNAL LOCATION payments_loc_1
URL 'abfss://gizmobox@deacoursestoragewestus2.dfs.core.windows.net/landing/external_data/payments'
WITH (STORAGE CREDENTIAL `dea_course_ext_sc`);

# %%
# %sql
CREATE EXTERNAL TABLE IF NOT EXISTS gizmobox.bronze.payments (
  payment_id INTEGER,
  order_id INTEGER,
  payment_timestamp TIMESTAMP,
  payment_status INTEGER,
  payment_method STRING
)
USING CSV
OPTIONS (
  header = "true",
  delimiter = ","
)
LOCATION '@dea_course_ext_dl_gizmobox/landing/external_data/payments/';

# %%
# %sql
DESCRIBE EXTERNAL LOCATION dea_course_ext_dl_gizmobox;

# %%
# %sql
SHOW VOLUMES IN gizmobox.bronze;

# %%
# %sql
USE CATALOG gizmobox;

# %%
# %sql
-- Check all volumes in the catalog
SHOW VOLUMES IN gizmobox.landing;

# %%
# %sql
CREATE EXTERNAL TABLE IF NOT EXISTS gizmobox.bronze.payments (
  payment_id INTEGER,
  order_id INTEGER,
  payment_timestamp TIMESTAMP,
  payment_status INTEGER,
  payment_method STRING
)
USING CSV
LOCATION 'abfss://gizmobox@deacoursestoragewestus2.dfs.core.windows.net/landing/external_data/payments';

# %%
# %sql
CREATE EXTERNAL TABLE IF NOT EXISTS gizmobox.bronze.payments (
  payment_id INTEGER,
  order_id INTEGER,
  payment_timestamp TIMESTAMP,
  payment_status INTEGER,
  payment_method STRING
)
USING CSV
LOCATION 'abfss://gizmobox@deacoursestoragewestus2.dfs.core.windows.net/landing/external_data/payments';

# %%
# %sql
DROP VOLUME IF EXISTS gizmobox.landing.external_data;

# %%
# %sql
CREATE EXTERNAL TABLE IF NOT EXISTS gizmobox.bronze.payments (
  payment_id INTEGER,
  order_id INTEGER,
  payment_timestamp TIMESTAMP,
  payment_status INTEGER,
  payment_method STRING
)
USING CSV
LOCATION 'abfss://gizmobox@deacoursestoragewestus2.dfs.core.windows.net/landing/external_data/payments';

# %%
# %sql
select * from gizmobox.bronze.payments;

# %%
# %sql
REFRESH TABLE gizmobox.bronze.payments;
