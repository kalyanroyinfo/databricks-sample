# %%
# %sql
SELECT * FROM gizmobox.bronze.v_customers
# Out:
# Databricks data profile. Run in Databricks to view.

# %%
df=spark.table('gizmobox.bronze.v_customers')
dbutils.data.summarize(df)

# %%
# %sql
SELECT COUNT(*),COUNT(customer_id)
FROM gizmobox.bronze.v_customers;

# %%
# %sql
SELECT COUNT_IF(customer_id IS NULL),COUNT_IF(email IS NULL)
FROM gizmobox.bronze.v_customers;

# %%
# %sql
SELECT COUNT(*) all_customer_id,COUNT(DISTINCT customer_id) unique_customer_id
FROM gizmobox.bronze.v_customers
WHERE customer_id IS NOT NULL;
